# %%
import pandas as pd
import cv2
import os
import shutil
import random

# %%
original_df = pd.read_csv('../csvs/dataset_sec_full20240812.csv')
original_df
# Out:
#                                                    id  good  defect  no_lens
# 0         210928-06.3.4-A001_20240131063150_1_R_1.jpg     0       1        0
# 1        211285-05.9.14-A002_20240131054210_0_R_1.jpg     0       1        0
# 2        211285-05.9.14-A002_20240131054210_2_R_1.jpg     0       1        0
# 3         220824-05.2.5-A002_20231229022825_2_L_1.jpg     0       1        0
# 4       221122-07.30.31-B001_20240124190550_1_R_1.jpg     0       1        0
# ...                                               ...   ...     ...      ...
# 275462  240730-09.28.26-B003_20240808103849_0_L_1.jpg     0       1        0
# 275463  240730-09.4.5.2-A002_20240808065047_0_R_1.jpg     0       1        0
# 275464  240731-08.10.11-B002_20240808093038_2_L_1.jpg     0       1        0
# 275465  240806-05.31.32-A001_20240810000745_3_L_1.jpg     0       1        0
# 275466    240807-07.1.4-B001_20240808162224_1_R_1.jpg     0       1        0
#
# [275467 rows x 4 columns]

# %%
filtered_df = original_df[~original_df['id'].str.contains('ud')]
filtered_df = filtered_df[~filtered_df['id'].str.contains('lr')]
filtered_df
# Out:
#                                                    id  good  defect  no_lens
# 0         210928-06.3.4-A001_20240131063150_1_R_1.jpg     0       1        0
# 1        211285-05.9.14-A002_20240131054210_0_R_1.jpg     0       1        0
# 2        211285-05.9.14-A002_20240131054210_2_R_1.jpg     0       1        0
# 3         220824-05.2.5-A002_20231229022825_2_L_1.jpg     0       1        0
# 4       221122-07.30.31-B001_20240124190550_1_R_1.jpg     0       1        0
# ...                                               ...   ...     ...      ...
# 275462  240730-09.28.26-B003_20240808103849_0_L_1.jpg     0       1        0
# 275463  240730-09.4.5.2-A002_20240808065047_0_R_1.jpg     0       1        0
# 275464  240731-08.10.11-B002_20240808093038_2_L_1.jpg     0       1        0
# 275465  240806-05.31.32-A001_20240810000745_3_L_1.jpg     0       1        0
# 275466    240807-07.1.4-B001_20240808162224_1_R_1.jpg     0       1        0
#
# [252705 rows x 4 columns]
